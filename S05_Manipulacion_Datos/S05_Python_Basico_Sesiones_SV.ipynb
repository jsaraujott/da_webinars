# %% [markdown]
# # Sprint 5 - Python Básico (Sesiones)
#
# **Versión para estudiantes**
#
# En estos ejercicios se busca practicar los siguientes conceptos básicos de programación en **Python**:
#
# * Manejo de variables
# * Manejo de cadenas de texto
# * Manejo de listas
# * Manejo de diccionarios
# * Definición y uso de funciones
# * Uso de bucles
# * Uso de condicionales

# %% [markdown]
# ## Manejo de variables

# %% [markdown]
# ### Ejercicio 1
#
# John tiene 25 años y su hermano 20. Asigna sus edades a las variables `john_age` y `brother_age`, e imprime en pantalla las variables.

# %% [markdown]
# Calcula la diferencia de edad en una nueva variable llamada `diff_ages`.

# %% [markdown]
# Calcula el promedio de edad en una nueva variable llamada `prom_ages`.

# %% [markdown]
# Muestra en pantalla la siguiente frase:
#
# *John tiene `john_age` años y su hermano tiene `brother_age`. La diferencia de edad entre ellos es `diff_ages` y su promedio es `prom_ages`.*

# %% [markdown]
# ### Ejercicio 2
#
# Escribe y rellena las siguientes variables con los valores respectivos:
#
# -   `name`: John
# -   `john_bitcoins`: 2.45
# -   `btc_to_usd`: 71000
# -   `has_driving_license`: True

# %% [markdown]
# Aplica la función `type` a cada una de ellas para mostrar el tipo de las variables.

# %% [markdown]
# Calcula e imprime la cantidad de bitcoins (BTC) que John mantiene en dólares estadounidenses.

# %% [markdown]
# ### Ejercicio 3
#
# John compró 1.3 bitcoins adicionales. Ejecuta el siguiente código y observa el error.
#
# ``` py
# john_bitcoins = '2.45'
#
# john_bitcoins = john_bitcoins + 1.3
# print(john_bitcoins)
# ```
#
# Ahora reescribe el código existente convirtiendo la variable `john_bitcoins` a `float` en el espacio disponible.

# %% [markdown]
# Ahora convierte los bitcoins de John a `int` e imprime la variable. ¿Ha perdido bitcoins?

# %% [markdown]
# ## Manejo de cadenas de texto
#
# ### Ejercicio 1
#
# John intentó enviar un mensaje de no más de 50 caracteres a su amigo Max para decirle que le había enviado bitcoins de regalo. Pero se equivocó al escribir el mensaje y el programa arrojó un error.
#
# ``` py
# message = 'Hey pal. I've sent you some bitcoins. Check your wallet!'
# print(message)
# ```
#
# Detecta el error y corrígelo usando caracteres de escape.

# %% [markdown]
# ¿Se ajusta el mensaje a la longitud deseada?

# %% [markdown]
# Una vez corregido y enviado el mensaje. Max respondió a John, pero el mensaje venía con algunos problemas:
#
# -   caracteres “\#” entre todas las palabras.
# -   Espacios tanto al principio como al final del mensaje.
# -   Letras en mayúsculas y minúsculas de forma aleatoria.
#
# ``` python
# message = "  hEY#bRO,#I#nEed#YouR#hElP#bUYiNg#bTc#tONigHt!     "
# ```
#
# Ayuda a John a entender el mensaje.

# %% [markdown]
# ### Ejercicio 2
#
# A John le encantan los secretos y por eso ha escondido sus claves de acceso a sus bitcoins en alguna parte. Para no olvidar dónde las guardó, creó un acertijo que solo los programadores de Python pueden descifrar. Dejó una frase escrita y varias instrucciones.
#
# La frase dice:
#
# *To my lovely wife I leave my key in the safe. Behind the statue of Dio you have a picture of us both.*
#
# Después dejó algunas instrucciones:
#
# -   A la longitud le restas 72, y luego la repites nuevamente pero que
#     72 se convierta en 69.
# -   Lo que está entre 33 y 35 es la segunda palabra.
# -   Si miras desde 44 hasta 38 no serás alguien **negativo**.
#
# ¿Dónde están escondidas las claves?

# %% [markdown]
# ## Manejo de listas
#
# ### Ejercicio 1
#
# Max quiere saber más sobre bitcoin y le pidió a John una lista de libros para leer. Su amigo le envió información sobre el libro “The Bitcoin Whitepaper” y le dijo que le enviaría más sugerencias después. Sin embargo, la información enviada está repartida en múltiples variables.
#
# ``` py
# title = 'The Bitcoin Whitepaper'
# country = 'USA'
# year = 2008
# genre = ['cryptocurrency', 'technology']
# ```
#
# Max quiere mantenerla unida en forma de lista para poder incluir después los otros libros en un mismo formato. Ayúdalo a hacerlo.

# %% [markdown]
# Imprime un `slice` de la lista creada que solamente contenga el nombre del país, el año y el género.

# %% [markdown]
# Imprime un `slice` de la lista creada que solamente contenga el nombre, el país y el año.

# %% [markdown]
# Imprime un `slice` de la lista creada que solamente contenga el nombre y el año.

# %% [markdown]
# ### Ejercicio 2
#
# John envió a Max una lista adicional de libros sobre bitcoin. Es un buen amigo, así que ya la envió en forma de lista de Python e incluso añadió los autores al final de esta lista. Pero hay un libro con más de un autor, y Max quiere dividir los autores y almacenarlos por separado en forma de sublista.
#
# ``` py
# books_all = [
#     ['Mastering Bitcoin', 'USA', 2014, ['cryptocurrency', 'technology'], 'Andreas M. Antonopoulos'],
#     ['The Age of Cryptocurrency', 'USA', 2015, ['cryptocurrency', 'economics'], 'Paul Vigna, Michael J. Casey'],
#     ['Digital Gold', 'USA', 2015, ['cryptocurrency', 'finance'], 'Nathaniel Popper'],
#     ['The Bitcoin Standard', 'USA', 2018, ['cryptocurrency', 'economics'], 'Saifedean Ammous'],
#     ['Bitcoin Billionaires', 'USA', 2019, ['cryptocurrency', 'biography'], 'Ben Mezrich']
# ]
# ```
#
# Busca el libro con más de un autor, extráelo utilizando indexación, divide los nombres de los autores en una nueva lista e imprime el resultado.

# %% [markdown]
# Modifica la lista original de forma que todos los autores aparezcan a modo de lista e imprime el resultado.

# %% [markdown]
# ### Ejercicio 3
#
# Ahora, Max quiere añadir la información de “The Bitcoin Whitepaper” a la lista de otros libros. Pero se dio cuenta de que John no le había mencionado al autor.
#
# Añade el autor, *Satoshi Nakamoto*, a la primera lista que Max había creado usando el método adecuado e imprímela.

# %% [markdown]
# Añade esta información al inicio de la lista de libros usando el método adecuado, e imprime el resultado.

# %% [markdown]
# ## Manejo de diccionarios

# %% [markdown]
# ### Ejercicio 1
#
# La empresa Aleph mantiene información de sus clientes, y te menciona que si bien todos los datos son correctos, quisiera que se trabaje con una estructura de datos tipo diccionario para garantizar la calidad de los registros históricos.
#
# Visto esto, crea un diccionario que contenga la información de nombre y edad según lo descrito a continuación:
#
# * Juan Araujo: 38
# * Pedro Paez: 46
# * Nicole Hadathy: 37
# * Cayetana Torres: 25
# * Diego Pino: 72
# * Pilar Montero: 69
#
# Utiliza el nombre como clave para el diccionario y llámalo `cliente_dicc`.

# %% [markdown]
# Consulta el diccionario para conocer la información de la cliente *Pilar Montero*.

# %% [markdown]
# El director de ventas de la empresa te indica que la edad de *Pedro Paez* no es correcta pues él tiene en realidad 43 años. Corrige el diccionario.

# %% [markdown]
# ### Ejercicio 2
#
# El mismo director de ventas de la empresa te indica que olvidó pasarte información de un cliente adicional, quien cuenta con la siguiente información:
#
# * Nombre: Sofía Pozo
# * Edad: 29
#
# Ingresa este nuevo cliente en el diccionario.

# %% [markdown]
# Por otra parte, te menciona que el cliente *Juan Araujo* prefiere ser tratado con su segundo nombre *Sebastián*, por lo que te pide hacer este ajuste en el diccionario. Para esto, primero elimina el registro existente, y posteriormente crea uno nuevo con la clave correcta.

# %% [markdown]
# ## Definición y uso de funciones

# %% [markdown]
# ### Ejercicio 1
#
# Escribe una función que tome un nombre cualquiera como entrada e imprima un mensaje de saludo.

# %% [markdown]
# Utiliza la función con uno de los nombres de clientes de Aleph.

# %% [markdown]
# ### Ejercicio 2
#
# Escribe una función que tome dos edades cualquiera como entrada y devuelva su promedio.

# %% [markdown]
# Utiliza la función con dos edades de clientes de Aleph. Guarda el resultado en una variable llamada `prom_edad` e imprímela.

# %% [markdown]
# ### Ejercicio 3
#
# Escribe una función que devuelva True (Verdadero) si un número cualquiera es par, y False en caso contrario.

# %% [markdown]
# Utiliza la función con dos edades distintas de clientes de forma que un resultado sea Verdadero y otro Falso.

# %% [markdown]
# ### Ejercicio 4
#
# Escriba una función que permita ingresar un nuevo cliente al diccionario. La función debe mostrar un mensaje indicando que el cliente se ha agregado satisfactoriamente y el tamaño del diccionario luego de que se ha agregado.

# %% [markdown]
# Utilice la función para agregar un nuevo cliente de nombre *Marcos Andrade* que tiene 51 años.

# %% [markdown]
# ## Uso de bucles

# %% [markdown]
# ### Ejercicio 1
#
# Utiliza un bucle `for` para transformar el diccionario de clientes en una lista anidada `cliente_list` donde cada sublista contenga como elementos el nombre y la edad de cada persona.

# %% [markdown]
# Con la lista obtenida y utilizando un bucle `for`, imprime para cada cliente un mensaje que diga lo siguiente:
#
# *El cliente de nombre (aquí va el nombre del cliente) tiene (aquí va su edad) años.*

# %% [markdown]
# ### Ejercicio 2
#
# Genera un saludo para todos los clientes. (Pista: Utiliza una de las funciones creadas previamente)

# %% [markdown]
# ### Ejercicio 3
#
# Utiliza un bucle `while` para recorrer la lista de clientes y mostrar la información del primer jubilado (mayor de 65 años) registrado.

# %% [markdown]
# ### Ejercicio 4
#
# Utiliza bucles for y while para crear una lista `clientes_rep` que contenga cada nombre de cliente repetido 3 veces.

# %% [markdown]
# ## Uso de condicionales

# %% [markdown]
# ### Ejercicio 1
#
# Recorre el diccionario de clientes y extrae en una lista `clientes_jovenes` todos los nombres de los clientes que tengan menos de 45 años.

# %% [markdown]
# ### Ejercicio 2
#
# Toma como referencia el código del ejercicio anterior de forma que ahora se guarden las edades de los clientes jóvenes en una lista llamada `edades_jovenes`, y en otra lista `edades_viejos` se guarden las edades de los clientes que no son jóvenes.

# %% [markdown]
# Calcula ahora el promedio de edades de clientes jóvenes y viejos e imprime los resultados con un mensaje adecuado.

# %% [markdown]
# ### Ejercicio 3
#
# Aleph busca generar campañas específicas de mercadeo para clientes menores a 30 años, otra para clientes entre 30 y 45 años, y una tercera para clientes cercanos a la jubilación (de igual o más de 45 años). Modifica el código generado en el ejercicio anterior a fin de que el mismo permita contar con listas de nombres de clientes en cada uno de los segmentos relevantes.
